# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="figures/k2_pix_small.png">
# *This notebook contains an excerpt instructional material from [gully](https://twitter.com/gully_) and the [K2 Guest Observer Office](https://keplerscience.arc.nasa.gov/); the content is available [on GitHub](https://github.com/gully/k2-metadata).*

# %% [markdown]
# <!--NAVIGATION-->
# < [K2 Guest Observer Proposal Information](01.01-Concatenate-Guest-Observer-proposals.ipynb) | [Contents](Index.ipynb) | [EPIC Catalog read in and save to feather](01.03-Read-EPIC-catalog-faster.ipynb) >

# %% [markdown]
# # EPIC Catalog Column Descriptions

# %% [markdown]
# The **Ecliptic Plane Input Catalog** (EPIC) has includes 67 pieces of metadata for virtually any conceivable stellar/galactic target for K2.  [Huber et al. 2016](http://adsabs.harvard.edu/abs/2016ApJS..224....2H) defined the catalog in detail.  In this and following Jupyter notebooks we show some techniques for working with the large catalog.
#
# Things to say:
# - Relevance of "k2_observed flag"
# - Need for Datatypes for saving memory while reading in
# - Reading in from the ApJ instead of from the crummy README file?

# %%
import pandas as pd
pd.set_option('display.max_rows',70)
import numpy as np

# %% [markdown]
# ## Catalog metadata and column descriptions

# %%
epic_readme = '../metadata/EPIC_catalog/README_epic.txt'

# %% [markdown]
# This file was not intended to be read as a conventional csv file.  Nevertheless, we can abuse pandas into reading it in two parts.

# %%
first3cols = pd.read_csv(epic_readme, skiprows=26, delimiter=r"\s+", usecols=[0,1,2], names='abc')
lastcol = pd.read_csv(epic_readme, skiprows=26, delimiter=r"\s\s\s+",usecols=[2], names='bcd', engine='python')
bad_rows = (first3cols.a == '###') | (first3cols.a.str.contains('---'))

# %%
df_comb = pd.concat([first3cols, lastcol], axis=1)[~bad_rows].reset_index(drop=True)

# %%
df_comb['a']=df_comb.a.str.strip('#').astype(int)

# %%
df_comb = df_comb.rename(columns={'a': 'col_num', 'b':'col_name', 
                        'c': 'data_format', 'd':'description'})

# %%
df_comb = df_comb.set_value(8, 'description', '... Stellar Properties Flag [not used]')
df_comb = df_comb.set_value(66, 'data_format', 'bool')
df_comb = df_comb.set_value(66, 'description', '1=target was observed, 0=target not observed')

# %%
df_comb.data_format.str[0].unique()
# Out:
# array(['I', 'A', 'D', 'E', 'b'], dtype=object)

# %% [markdown]
# > The lack of NaN rep in integer columns is a pandas "gotcha".
# - https://stackoverflow.com/questions/21287624/convert-pandas-column-containing-nans-to-dtype-int

# %%
df_comb
# Out:
#     col_num       col_name data_format  \
# 0         1             ID         I10
# 1         2            HIP          I8
# 2         3            TYC         A15
# 3         4           UCAC         A15
# 4         5          2MASS         A20
# 5         6           SDSS         A20
# 6         7        Objtype         A10
# 7         8        Kepflag          A5
# 8         9     StpropFlag          A5
# 9        10             RA       D10.6
# 10       11            DEC       D10.6
# 11       12           pmRA       D10.3
# 12       13         e_pmRA       D10.3
# 13       14          pmDEC       D10.3
# 14       15        e_pmDEC       D10.3
# 15       16            plx       D10.3
# 16       17          e_plx       D10.3
# 17       18           Bmag        D6.3
# 18       19         e_Bmag        D6.3
# 19       20           Vmag        D6.3
# 20       21         e_Vmag        D6.3
# 21       22           umag        D6.3
# 22       23         e_umag        D6.3
# 23       24           gmag        D6.3
# 24       25         e_gmag        D6.3
# 25       26           rmag        D6.3
# 26       27         e_rmag        D6.3
# 27       28           imag        D6.3
# 28       29         e_imag        D6.3
# 29       30           zmag        D6.3
# 30       31         e_zmag        D6.3
# 31       32           Jmag        D6.3
# 32       33         e_Jmag        D6.3
# 33       34           Hmag        D6.3
# 34       35         e_Hmag        D6.3
# 35       36           Kmag        D6.3
# 36       37         e_Kmag        D6.3
# 37       38          W1mag        D6.3
# 38       39        e_W1mag        D6.3
# 39       40          W2mag        D6.3
# 40       41        e_W2mag        D6.3
# 41       42          W3mag        D6.3
# 42       43        e_W3mag        D6.3
# 43       44          W4mag        D6.3
# 44       45        e_W4mag        D6.3
# 45       46             Kp        D6.3
# 46       47           Teff        D6.0
# 47       48         e_Teff        D6.0
# 48       49           logg        D6.3
# 49       50         e_logg        D6.3
# 50       51         [Fe/H]        D6.3
# 51       52       e_[Fe/H]        D6.3
# 52       53            Rad        D8.3
# 53       54          e_Rad        D8.3
# 54       55           Mass        D8.3
# 55       56         e_Mass        D8.3
# 56       57            rho       E10.3
# 57       58          e_rho       E10.3
# 58       59            Lum       E10.3
# 59       60          e_Lum       E10.3
# 60       61              d        D8.1
# 61       62            e_d        D8.1
# 62       63         E(B-V)        D6.3
# 63       64          NOMAD         A20
# 64       65           Mflg         A20
# 65       66           prox        D6.3
# 66       67  k2_avail_flag        bool
#
#                                           description
# 0                     ... K2 Input Catalog Identifier
# 1                            ... Hipparcos Identifier
# 2                               ... Tycho2 Identifier
# 3                                ... UCAC4 Identifier
# 4                                ... 2MASS Identifier
# 5                             ... SDSS DR9 Identifier
# 6                     ... Object Type [STAR,EXTENDED]
# 7            ... Kepler Magnitude Flag [gri,BV,JHK,J]
# 8              ... Stellar Properties Flag [not used]
# 9                    ... Right Ascension JD2000 (Deg)
# 10                       ... Declination JD2000 (Deg)
# 11                   ... Proper motion in RA (mas/yr)
# 12    ... Uncertainty in Proper motion in RA (mas/yr)
# 13                  ... Proper motion in DEC (mas/yr)
# 14   ... Uncertainty in Proper motion in DEC (mas/yr)
# 15                       ... Hipparcos parallax (mas)
# 16                  ... Uncertainty in parallax (mas)
# 17                      ... Johnson B Magnitude (mag)
# 18       ... Uncertainty in Johnson B Magnitude (mag)
# 19                      ... Johnson V Magnitude (mag)
# 20       ... Uncertainty in Johnson V Magnitude (mag)
# 21                        ... Sloan u Magnitude (mag)
# 22         ... Uncertainty in Sloan u Magnitude (mag)
# 23                        ... Sloan g Magnitude (mag)
# 24         ... Uncertainty in Sloan g Magnitude (mag)
# 25                        ... Sloan r Magnitude (mag)
# 26         ... Uncertainty in Sloan r Magnitude (mag)
# 27                        ... Sloan i Magnitude (mag)
# 28         ... Uncertainty in Sloan i Magnitude (mag)
# 29                        ... Sloan z Magnitude (mag)
# 30         ... Uncertainty in Sloan z Magnitude (mag)
# 31                        ... 2MASS J Magnitude (mag)
# 32         ... Uncertainty in 2MASS J Magnitude (mag)
# 33                        ... 2MASS H Magnitude (mag)
# 34         ... Uncertainty in 2MASS H Magnitude (mag)
# 35                        ... 2MASS K Magnitude (mag)
# 36         ... Uncertainty in 2MASS K Magnitude (mag)
# 37                        ... WISE W1 Magnitude (mag)
# 38         ... Uncertainty in WISE W1 Magnitude (mag)
# 39                        ... WISE W2 Magnitude (mag)
# 40         ... Uncertainty in WISE W2 Magnitude (mag)
# 41                        ... WISE W3 Magnitude (mag)
# 42         ... Uncertainty in WISE W3 Magnitude (mag)
# 43                        ... WISE W4 Magnitude (mag)
# 44         ... Uncertainty in WISE W4 Magnitude (mag)
# 45                         ... Kepler Magnitude (mag)
# 46                      ... Effective Temperature (K)
# 47       ... Uncertainty in Effective Temperature (K)
# 48                      ... log Surface Gravity (cgs)
# 49       ... Uncertainty in log Surface Gravity (cgs)
# 50                              ... Metallicity (dex)
# 51               ... Uncertainty in Metallicity (dex)
# 52                   ... Stellar Radius (solar units)
# 53    ... Uncertainty in Stellar Radius (solar units)
# 54                     ... Stellar Mass (solar units)
# 55      ... Uncertainty in Stellar Mass (solar units)
# 56                  ... Stellar Density (solar units)
# 57   ... Uncertainty in Stellar Density (solar units)
# 58               ... Stellar Luminosity (solar units)
# 59  ... Uncertainty in Stellar Luminosity (solar u...
# 60                                  ... Distance (pc)
# 61          ... Uncertainty in Distance (solar units)
# 62                               ... Extinction (mag)
# 63  ... NOMAD1 Identifier [for sources with supple...
# 64    ... 2MASS Flags [Qflg-Rflg-Bflg-Cflg-Xflg-Aflg]
# 65       ... 2MASS nearest neighbor distance (arcsec)
# 66       1=target was observed, 0=target not observed

# %%
df_comb['name'] = df_comb.col_name.str.lower()

# %%
df_comb.to_csv('../metadata/EPIC_catalog/column_dtypes.csv', index=False)

# %% [markdown]
# The end

# %% [markdown]
# <!--NAVIGATION-->
# < [K2 Guest Observer Proposal Information](01.01-Concatenate-Guest-Observer-proposals.ipynb) | [Contents](Index.ipynb) | [EPIC Catalog read in and save to feather](01.03-Read-EPIC-catalog-faster.ipynb) >
